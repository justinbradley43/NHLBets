# %% [markdown]
# # Prototype models with (familiar) Keras

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.optimizers import Adam

# %%
def train_model(input_name:str, output_name:str) -> None:
    # read data
    df = pd.read_csv(input_name)
    X = df.drop('Outcome', axis=1)
    y = df['Outcome']

    # convert data to arrays
    X = np.array(X)
    y = np.array(y)

    # split data into the appropriate groups
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

    # scale X data
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # build layers
    model = Sequential()
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.1))
    model.add(Dense(512, activation='relu'))
    #model.add(Dropout(0.1))
    #model.add(Dense(64, activation='relu'))
    #model.add(Dropout(0.1))
    #model.add(Dense(64, activation='relu'))
    #model.add(Dropout(0.1))
    #model.add(Dense(64, activation='relu'))
    #model.add(Dropout(0.1))
    #model.add(Dense(32, activation='relu'))
    model.add(Dropout(0.1))
    model.add(Dense(1, activation='sigmoid'))

    # define model with appropriate loss function and metric
    model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.0001), metrics=['mse'])

    # fit model and print accuracy
    history = model.fit(X_train, y_train, epochs=50, batch_size=64, validation_data=(X_test, y_test))
    print(model.evaluate(X_test, y_test))
    model.save(output_name)

# %%
train_model("csvs/ml_X.csv", "built_models/keras_ml.h5")
# best has been .0001 lr, 64 bs, 2 layers of 512, bce, mse
# Out:
# Epoch 1/50
# 286/286 [==============================] - 3s 7ms/step - loss: 0.6947 - mse: 0.2498 - val_loss: 0.6572 - val_mse: 0.2325
# Epoch 2/50
# 286/286 [==============================] - 2s 6ms/step - loss: 0.6475 - mse: 0.2280 - val_loss: 0.6408 - val_mse: 0.2248
# Epoch 3/50
# 286/286 [==============================] - 2s 6ms/step - loss: 0.6133 - mse: 0.2124 - val_loss: 0.6265 - val_mse: 0.2184
# Epoch 4/50
# 286/286 [==============================] - 2s 6ms/step - loss: 0.5879 - mse: 0.2009 - val_loss: 0.6104 - val_mse: 0.2109
# Epoch 5/50
# 286/286 [==============================] - 2s 6ms/step - loss: 0.5595 - mse: 0.1886 - val_loss: 0.5952 - val_mse: 0.2042
# Epoch 6/50
# 286/286 [==============================] - 2s 6ms/step - loss: 0.5302 - mse: 0.1758 - val_loss: 0.5825 - val_mse: 0.1985
# Epoch 7/50
# 286/286 [==============================] - 2s 6ms/step - loss: 0.5055 - mse: 0.1654 - val_loss: 0.5658 - val_mse: 0.1908
# Epoch 8/50
# 286/286 [==============================] - 2s 6ms/step - loss: 0.4755 - mse: 0.1530 - val_loss: 0.5488 - val_mse: 0.1837
# Epoch 9/50
# 286/286 [==============================] - 2s 7ms/step - loss: 0.4487 - mse: 0.1426 - val_loss: 0.5313 - val_mse: 0.1761
# Epoch 10/50
# 286/286 [==============================] - 2s 6ms/step - loss: 0.4216 - mse: 0.1318 - val_loss: 0.5191 - val_mse: 0.1710
# Epoch 11/50
# 286/286 [==============================] - 2s 7ms/step - loss: 0.3973 - mse: 0.1228 - val_loss: 0.5034 - val_mse: 0.1648
# Epoch 12/50
# 286/286 [==============================] - 2s 6ms/step - loss: 0.3711 - mse: 0.1126 - val_loss: 0.4850 - val_mse: 0.1577
# Epoch 13/50
# 286/286 [==============================] - 2s 6ms/step - loss: 0.3433 - mse: 0.1026 - val_loss: 0.4694 - val_mse: 0.1509
# Epoch 14/50
# 286/286 [==============================] - 2s 6ms/step - loss: 0.3223 - mse: 0.0948 - val_loss: 0.4450 - val_mse: 0.1411
# Epoch 15/50
# 286/286 [==============================] - 2s 6ms/step - loss: 0.2977 - mse: 0.0865 - val_loss: 0.4358 - val_mse: 0.1374
# Epoch 16/50
# 286/286 [==============================] - 2s 6ms/step - loss: 0.2779 - mse: 0.0794 - val_loss: 0.4263 - val_mse: 0.1332
# Epoch 17/50
# 286/286 [==============================] - 2s 7ms/step - loss: 0.2587 - mse: 0.0732 - val_loss: 0.4047 - val_mse: 0.1248
# Epoch 18/50
# 286/286 [==============================] - 2s 7ms/step - loss: 0.2428 - mse: 0.0678 - val_loss: 0.3836 - val_mse: 0.1160
# Epoch 19/50
# 286/286 [==============================] - 2s 7ms/step - loss: 0.2274 - mse: 0.0627 - val_loss: 0.3778 - val_mse: 0.1140
# Epoch 20/50
# 286/286 [==============================] - 2s 7ms/step - loss: 0.2145 - mse: 0.0590 - val_loss: 0.3648 - val_mse: 0.1081
# Epoch 21/50
# 286/286 [==============================] - 2s 7ms/step - loss: 0.2036 - mse: 0.0553 - val_loss: 0.3485 - val_mse: 0.1023
# Epoch 22/50
# 286/286 [==============================] - 2s 6ms/step - loss: 0.1846 - mse: 0.0491 - val_loss: 0.3413 - val_mse: 0.0994
# Epoch 23/50
# 286/286 [==============================] - 2s 6ms/step - loss: 0.1791 - mse: 0.0477 - val_loss: 0.3358 - val_mse: 0.0968
# Epoch 24/50
# 286/286 [==============================] - 2s 6ms/step - loss: 0.1659 - mse: 0.0438 - val_loss: 0.3242 - val_mse: 0.0931
# Epoch 25/50
# 286/286 [==============================] - 2s 6ms/step - loss: 0.1541 - mse: 0.0398 - val_loss: 0.3147 - val_mse: 0.0884
# Epoch 26/50
# 286/286 [==============================] - 2s 7ms/step - loss: 0.1475 - mse: 0.0385 - val_loss: 0.3134 - val_mse: 0.0877
# Epoch 27/50
# 286/286 [==============================] - 2s 6ms/step - loss: 0.1337 - mse: 0.0338 - val_loss: 0.2982 - val_mse: 0.0828
# Epoch 28/50
# 286/286 [==============================] - 2s 6ms/step - loss: 0.1282 - mse: 0.0323 - val_loss: 0.3029 - val_mse: 0.0832
# Epoch 29/50
# 286/286 [==============================] - 2s 7ms/step - loss: 0.1209 - mse: 0.0303 - val_loss: 0.2950 - val_mse: 0.0808
# Epoch 30/50
# 286/286 [==============================] - 2s 7ms/step - loss: 0.1148 - mse: 0.0285 - val_loss: 0.2922 - val_mse: 0.0779
# Epoch 31/50
# 286/286 [==============================] - 2s 7ms/step - loss: 0.1073 - mse: 0.0265 - val_loss: 0.2875 - val_mse: 0.0766
# Epoch 32/50
# 286/286 [==============================] - 2s 6ms/step - loss: 0.1008 - mse: 0.0245 - val_loss: 0.2849 - val_mse: 0.0769
# Epoch 33/50
# 286/286 [==============================] - 2s 6ms/step - loss: 0.0944 - mse: 0.0228 - val_loss: 0.2826 - val_mse: 0.0751
# Epoch 34/50
# 286/286 [==============================] - 2s 7ms/step - loss: 0.0936 - mse: 0.0230 - val_loss: 0.2845 - val_mse: 0.0763
# Epoch 35/50
# 286/286 [==============================] - 2s 7ms/step - loss: 0.0844 - mse: 0.0199 - val_loss: 0.2811 - val_mse: 0.0750
# Epoch 36/50
# 286/286 [==============================] - 2s 6ms/step - loss: 0.0829 - mse: 0.0200 - val_loss: 0.2823 - val_mse: 0.0734
# Epoch 37/50
# 286/286 [==============================] - 2s 7ms/step - loss: 0.0802 - mse: 0.0190 - val_loss: 0.2740 - val_mse: 0.0726
# Epoch 38/50
# 286/286 [==============================] - 2s 6ms/step - loss: 0.0721 - mse: 0.0167 - val_loss: 0.2733 - val_mse: 0.0716
# Epoch 39/50
# 286/286 [==============================] - 2s 6ms/step - loss: 0.0688 - mse: 0.0159 - val_loss: 0.2704 - val_mse: 0.0704
# Epoch 40/50
# 286/286 [==============================] - 2s 6ms/step - loss: 0.0690 - mse: 0.0160 - val_loss: 0.2864 - val_mse: 0.0728
# Epoch 41/50
# 286/286 [==============================] - 2s 6ms/step - loss: 0.0669 - mse: 0.0158 - val_loss: 0.2815 - val_mse: 0.0729
# Epoch 42/50
# 286/286 [==============================] - 2s 6ms/step - loss: 0.0614 - mse: 0.0142 - val_loss: 0.2842 - val_mse: 0.0723
# Epoch 43/50
# 286/286 [==============================] - 2s 6ms/step - loss: 0.0570 - mse: 0.0129 - val_loss: 0.2836 - val_mse: 0.0730
# Epoch 44/50
# 286/286 [==============================] - 2s 6ms/step - loss: 0.0560 - mse: 0.0128 - val_loss: 0.2819 - val_mse: 0.0707
# Epoch 45/50
# 286/286 [==============================] - 2s 6ms/step - loss: 0.0550 - mse: 0.0127 - val_loss: 0.2782 - val_mse: 0.0700
# Epoch 46/50
# 286/286 [==============================] - 2s 7ms/step - loss: 0.0533 - mse: 0.0122 - val_loss: 0.2849 - val_mse: 0.0729
# Epoch 47/50
# 286/286 [==============================] - 2s 7ms/step - loss: 0.0483 - mse: 0.0108 - val_loss: 0.2919 - val_mse: 0.0725
# Epoch 48/50
# 286/286 [==============================] - 2s 7ms/step - loss: 0.0460 - mse: 0.0103 - val_loss: 0.2953 - val_mse: 0.0714
# Epoch 49/50
# 286/286 [==============================] - 2s 6ms/step - loss: 0.0475 - mse: 0.0109 - val_loss: 0.2906 - val_mse: 0.0712
# Epoch 50/50
# 286/286 [==============================] - 2s 6ms/step - loss: 0.0439 - mse: 0.0097 - val_loss: 0.2847 - val_mse: 0.0714
# 143/143 [==============================] - 0s 2ms/step - loss: 0.2847 - mse: 0.0714
# [0.28472140431404114, 0.07138265669345856]
# C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
train_model("csvs/ou_X.csv", "built_models/keras_ou.h5")
# Out:
# Epoch 1/35
# 571/571 [==============================] - 2s 3ms/step - loss: 0.6995 - accuracy: 0.5027 - val_loss: 0.6925 - val_accuracy: 0.5256
# Epoch 2/35
# 571/571 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.5191 - val_loss: 0.6929 - val_accuracy: 0.5256
# Epoch 3/35
# 571/571 [==============================] - 2s 3ms/step - loss: 0.6926 - accuracy: 0.5182 - val_loss: 0.6924 - val_accuracy: 0.5258
# Epoch 4/35
# 571/571 [==============================] - 1s 3ms/step - loss: 0.6925 - accuracy: 0.5208 - val_loss: 0.6925 - val_accuracy: 0.5256
# Epoch 5/35
# 571/571 [==============================] - 1s 3ms/step - loss: 0.6925 - accuracy: 0.5205 - val_loss: 0.6929 - val_accuracy: 0.5256
# Epoch 6/35
# 571/571 [==============================] - 1s 3ms/step - loss: 0.6923 - accuracy: 0.5206 - val_loss: 0.6926 - val_accuracy: 0.5256
# Epoch 7/35
# 571/571 [==============================] - 2s 3ms/step - loss: 0.6924 - accuracy: 0.5197 - val_loss: 0.6939 - val_accuracy: 0.5256
# Epoch 8/35
# 571/571 [==============================] - 1s 3ms/step - loss: 0.6924 - accuracy: 0.5217 - val_loss: 0.6926 - val_accuracy: 0.5256
# Epoch 9/35
# 571/571 [==============================] - 2s 3ms/step - loss: 0.6923 - accuracy: 0.5212 - val_loss: 0.6924 - val_accuracy: 0.5256
# Epoch 10/35
# 571/571 [==============================] - 2s 3ms/step - loss: 0.6924 - accuracy: 0.5216 - val_loss: 0.6923 - val_accuracy: 0.5256
# Epoch 11/35
# 571/571 [==============================] - 2s 3ms/step - loss: 0.6925 - accuracy: 0.5215 - val_loss: 0.6927 - val_accuracy: 0.5256
# Epoch 12/35
# 571/571 [==============================] - 2s 3ms/step - loss: 0.6923 - accuracy: 0.5213 - val_loss: 0.6925 - val_accuracy: 0.5256
# Epoch 13/35
# 571/571 [==============================] - 2s 3ms/step - loss: 0.6921 - accuracy: 0.5211 - val_loss: 0.6921 - val_accuracy: 0.5256
# Epoch 14/35
# 571/571 [==============================] - 2s 3ms/step - loss: 0.6921 - accuracy: 0.5214 - val_loss: 0.6928 - val_accuracy: 0.5256
# Epoch 15/35
# 571/571 [==============================] - 1s 3ms/step - loss: 0.6923 - accuracy: 0.5214 - val_loss: 0.6922 - val_accuracy: 0.5256
# Epoch 16/35
# 571/571 [==============================] - 1s 2ms/step - loss: 0.6922 - accuracy: 0.5210 - val_loss: 0.6961 - val_accuracy: 0.5256
# Epoch 17/35
# 571/571 [==============================] - 1s 3ms/step - loss: 0.6919 - accuracy: 0.5210 - val_loss: 0.6926 - val_accuracy: 0.5256
# Epoch 18/35
# 571/571 [==============================] - 2s 3ms/step - loss: 0.6917 - accuracy: 0.5222 - val_loss: 0.6948 - val_accuracy: 0.4855
# Epoch 19/35
# 571/571 [==============================] - 2s 3ms/step - loss: 0.6922 - accuracy: 0.5215 - val_loss: 0.6939 - val_accuracy: 0.5256
# Epoch 20/35
# 571/571 [==============================] - 2s 3ms/step - loss: 0.6918 - accuracy: 0.5218 - val_loss: 0.6947 - val_accuracy: 0.5256
# Epoch 21/35
# 571/571 [==============================] - 2s 3ms/step - loss: 0.6916 - accuracy: 0.5212 - val_loss: 0.6967 - val_accuracy: 0.5256
# Epoch 22/35
# 571/571 [==============================] - 2s 3ms/step - loss: 0.6910 - accuracy: 0.5214 - val_loss: 0.6977 - val_accuracy: 0.5256
# Epoch 23/35
# 571/571 [==============================] - 2s 3ms/step - loss: 0.6910 - accuracy: 0.5211 - val_loss: 0.6978 - val_accuracy: 0.5256
# Epoch 24/35
# 571/571 [==============================] - 1s 3ms/step - loss: 0.6900 - accuracy: 0.5217 - val_loss: 0.6967 - val_accuracy: 0.5254
# Epoch 25/35
# 571/571 [==============================] - 1s 3ms/step - loss: 0.6886 - accuracy: 0.5203 - val_loss: 0.7046 - val_accuracy: 0.5256
# Epoch 26/35
# 571/571 [==============================] - 2s 3ms/step - loss: 0.6872 - accuracy: 0.5214 - val_loss: 0.7119 - val_accuracy: 0.5256
# Epoch 27/35
# 571/571 [==============================] - 2s 3ms/step - loss: 0.6848 - accuracy: 0.5209 - val_loss: 0.7082 - val_accuracy: 0.5256
# Epoch 28/35
# 571/571 [==============================] - 2s 3ms/step - loss: 0.6836 - accuracy: 0.5216 - val_loss: 0.7199 - val_accuracy: 0.5256
# Epoch 29/35
# 571/571 [==============================] - 1s 3ms/step - loss: 0.6813 - accuracy: 0.5203 - val_loss: 0.7419 - val_accuracy: 0.5256
# Epoch 30/35
# 571/571 [==============================] - 1s 3ms/step - loss: 0.6794 - accuracy: 0.5212 - val_loss: 0.7215 - val_accuracy: 0.5256
# Epoch 31/35
# 571/571 [==============================] - 2s 3ms/step - loss: 0.6745 - accuracy: 0.5227 - val_loss: 0.7321 - val_accuracy: 0.4505
# Epoch 32/35
# 571/571 [==============================] - 2s 3ms/step - loss: 0.6736 - accuracy: 0.5250 - val_loss: 0.7540 - val_accuracy: 0.4406
# Epoch 33/35
# 571/571 [==============================] - 1s 3ms/step - loss: 0.6698 - accuracy: 0.5288 - val_loss: 0.7491 - val_accuracy: 0.4481
# Epoch 34/35
# 571/571 [==============================] - 1s 3ms/step - loss: 0.6680 - accuracy: 0.5325 - val_loss: 0.8704 - val_accuracy: 0.4437
# Epoch 35/35
# 571/571 [==============================] - 2s 3ms/step - loss: 0.6655 - accuracy: 0.5353 - val_loss: 0.9101 - val_accuracy: 0.4424
# 143/143 [==============================] - 0s 1ms/step - loss: 0.9101 - accuracy: 0.4424
# [0.9101384878158569, 0.44240033626556396]
# C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
train_model("csvs/pl_X.csv", "built_models/keras_pl.h5")
# Out:
# Epoch 1/35
# 286/286 [==============================] - 2s 3ms/step - loss: 0.6999 - accuracy: 0.5387 - val_loss: 0.6840 - val_accuracy: 0.5714
# Epoch 2/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.6773 - accuracy: 0.5838 - val_loss: 0.6956 - val_accuracy: 0.5788
# Epoch 3/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.6618 - accuracy: 0.6208 - val_loss: 0.6689 - val_accuracy: 0.6187
# Epoch 4/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.6466 - accuracy: 0.6311 - val_loss: 0.6619 - val_accuracy: 0.6187
# Epoch 5/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.6375 - accuracy: 0.6467 - val_loss: 0.6661 - val_accuracy: 0.6143
# Epoch 6/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.6284 - accuracy: 0.6518 - val_loss: 0.6729 - val_accuracy: 0.6270
# Epoch 7/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.6207 - accuracy: 0.6582 - val_loss: 0.6839 - val_accuracy: 0.6130
# Epoch 8/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.6042 - accuracy: 0.6694 - val_loss: 0.6836 - val_accuracy: 0.6051
# Epoch 9/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.5941 - accuracy: 0.6800 - val_loss: 0.7051 - val_accuracy: 0.5858
# Epoch 10/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.5760 - accuracy: 0.6902 - val_loss: 0.7167 - val_accuracy: 0.5898
# Epoch 11/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.5590 - accuracy: 0.7075 - val_loss: 0.7310 - val_accuracy: 0.5876
# Epoch 12/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.5380 - accuracy: 0.7209 - val_loss: 0.7486 - val_accuracy: 0.5792
# Epoch 13/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.5128 - accuracy: 0.7384 - val_loss: 0.8105 - val_accuracy: 0.5749
# Epoch 14/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.4929 - accuracy: 0.7545 - val_loss: 0.7974 - val_accuracy: 0.5806
# Epoch 15/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.4696 - accuracy: 0.7678 - val_loss: 0.8296 - val_accuracy: 0.5753
# Epoch 16/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.4447 - accuracy: 0.7849 - val_loss: 0.9172 - val_accuracy: 0.5766
# Epoch 17/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.4183 - accuracy: 0.8004 - val_loss: 0.9692 - val_accuracy: 0.5705
# Epoch 18/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.4012 - accuracy: 0.8095 - val_loss: 0.9573 - val_accuracy: 0.5613
# Epoch 19/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.3640 - accuracy: 0.8351 - val_loss: 0.9536 - val_accuracy: 0.5604
# Epoch 20/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.3535 - accuracy: 0.8435 - val_loss: 1.0335 - val_accuracy: 0.5447
# Epoch 21/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.3270 - accuracy: 0.8540 - val_loss: 1.0754 - val_accuracy: 0.5674
# Epoch 22/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.3148 - accuracy: 0.8628 - val_loss: 1.1354 - val_accuracy: 0.5622
# Epoch 23/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.2878 - accuracy: 0.8769 - val_loss: 1.2577 - val_accuracy: 0.5504
# Epoch 24/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.2727 - accuracy: 0.8843 - val_loss: 1.3000 - val_accuracy: 0.5569
# Epoch 25/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.2498 - accuracy: 0.8987 - val_loss: 1.3170 - val_accuracy: 0.5451
# Epoch 26/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.2442 - accuracy: 0.8971 - val_loss: 1.3636 - val_accuracy: 0.5547
# Epoch 27/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.2448 - accuracy: 0.8986 - val_loss: 1.2378 - val_accuracy: 0.5604
# Epoch 28/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.2200 - accuracy: 0.9114 - val_loss: 1.3651 - val_accuracy: 0.5517
# Epoch 29/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.2188 - accuracy: 0.9123 - val_loss: 1.4115 - val_accuracy: 0.5517
# Epoch 30/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.2055 - accuracy: 0.9169 - val_loss: 1.3249 - val_accuracy: 0.5560
# Epoch 31/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.2047 - accuracy: 0.9185 - val_loss: 1.3309 - val_accuracy: 0.5569
# Epoch 32/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.1817 - accuracy: 0.9262 - val_loss: 1.4944 - val_accuracy: 0.5552
# Epoch 33/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.1781 - accuracy: 0.9302 - val_loss: 1.5138 - val_accuracy: 0.5499
# Epoch 34/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.1837 - accuracy: 0.9304 - val_loss: 1.4518 - val_accuracy: 0.5670
# Epoch 35/35
# 286/286 [==============================] - 1s 3ms/step - loss: 0.1646 - accuracy: 0.9381 - val_loss: 1.5908 - val_accuracy: 0.5530
# 72/72 [==============================] - 0s 1ms/step - loss: 1.5908 - accuracy: 0.5530
# [1.5908173322677612, 0.5529772043228149]
# C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
